# %%
import pandas as pd
import json
import random
from sklearn.model_selection import train_test_split
from datetime import datetime

# %% [markdown]
# ## Import RadLex codes and descriptions from BioPortal
# Link here: https://bioportal.bioontology.org/ontologies/RADLEX

# %%
# Load ICD diagnoses dictionary
radlex_file_path = 'RADLEX.csv'  # Replace with your actual file path
radlex_data = pd.read_csv(radlex_file_path)
# Out:
# /var/folders/6_/tm5pls9x65n1g2wjy2xsytg40000gn/T/ipykernel_38506/2309171745.py:3: DtypeWarning: Columns (12,14,29,32,35,42,46,47,48,56,73,76,77,78,83,85,86,156) have mixed types. Specify dtype option on import or set low_memory=False.
#   radlex_data = pd.read_csv(radlex_file_path)

# %%
radlex_data.head(2)
# Out:
#                              Class ID  \
# 0  http://www.radlex.org/RID/RID32370
# 1  http://www.radlex.org/RID/RID21755
#
#                                      Preferred Label Synonyms Definitions  \
# 0  left fourth anterior cervical intertransversarius      NaN         NaN
# 1  trunk of pharyngeal branch of right glossophar...      NaN         NaN
#
#    Obsolete  CUI  Semantic Types                             Parents  \
# 0     False  NaN             NaN  http://www.radlex.org/RID/RID32368
# 1     False  NaN             NaN  http://www.radlex.org/RID/RID21754
#
#   http://data.bioontology.org/metadata/prefixIRI  http://radlex.org/RID/AAL  \
# 0                                  RID1:RID32370                        NaN
# 1                                  RID1:RID21755                        NaN
#
#    ... http://www.radlex.org/RID/Surrounded_by  \
# 0  ...                                     NaN
# 1  ...                                     NaN
#
#   http://www.radlex.org/RID/Surrounds http://www.radlex.org/RID/Synonym  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
#
#   http://www.radlex.org/RID/Synonym_German  \
# 0                                      NaN
# 1                                      NaN
#
#   http://www.radlex.org/RID/Talairach http://www.radlex.org/RID/Term_type  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#   http://www.radlex.org/RID/Tributary_Of http://www.radlex.org/RID/UMLS_ID  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
#
#   http://www.radlex.org/RID/UMLS_Term  \
# 0                                 NaN
# 1                                 NaN
#
#   http://www.radlex.org/RID/Unsanctioned_Term
# 0                                         NaN
# 1                                         NaN
#
# [2 rows x 170 columns]

# %%
radlex_data.shape
# Out:
# (46840, 170)

# %%
radlex_data.rename(columns=lambda col: col.replace("http://radlex.org/RID/", "") if col.startswith("http://radlex.org/RID/") else col, inplace=True)
radlex_data.rename(columns=lambda col: col.replace("http://www.radlex.org/RID/", "") if col.startswith("http://www.radlex.org/RID/") else col, inplace=True)

for col in radlex_data.columns:
    print(col)
# Out:
# Class ID
# Preferred Label
# Synonyms
# Definitions
# Obsolete
# CUI
# Semantic Types
# Parents
# http://data.bioontology.org/metadata/prefixIRI
# AAL
# Acronym
# Anatomical_Site
# Anterior_to
# Attaches_to
# Blood_Supply_of
# Bounded_by
# Bounds
# Branch_Of
# CMA_Label
# Comment
# Constitutional_Part_Of
# Contained_In
# Contains
# Continuous_With
# Created
# Definition
# Distal_to
# Domain_string
# Drains_Into
# External_to
# FMAID
# Freesurfer
# Has_Blood_Supply
# Has_Branch
# Has_Constitutional_Part
# Has_Entrapment_Site
# Has_Innervation_Source
# Has_insertion
# Has_Member
# Has_origin
# Has_Part
# Has_Regional_Part
# Inferior_to
# Innervates
# Insertion_of
# JHU_DTI-81
# JHU_White-Matter_Tractography_Atlas
# Lymphatic_Drainage
# Lymphatic_Drainage_Of
# May_Be_Caused_By
# May_Cause
# Member_Of
# Misspelling_of_term
# name
# Origin_of
# Part_Of
# Posterior_to
# Preferred_name
# Preferred_Name_for_Obsolete
# Preferred_name_German
# Projects_From
# Projects_To
# Proximal_to
# Radlex_version_of_class_change
# Receives_attachment_from
# Receives_Drainage_From
# Receives_Input_From
# Receives_Projection_From
# Regional_Part_Of
# Related_modality
# Replaced_by
# Segment_Of
# Sends_Output_To
# SNOMED_ID
# SNOMED_Term
# Source
# Superior_to
# Surrounded_by
# Surrounds
# Synonym
# Synonym_German
# Talairach
# Term_type
# Tributary_Of
# UMLS_ID
# UMLS_Term
# Unsanctioned_Term
# http://www.geneontology.org/formats/oboInOwl#created_by
# http://www.geneontology.org/formats/oboInOwl#creation_date
# AAL
# Acronym
# Anatomical_Site
# Anterior_to
# Attaches_to
# Blood_Supply_of
# Bounded_by
# Bounds
# Branch_Of
# Branch_Part_of
# CMA_Label
# Comment
# Constitutional_Part_Of
# Contained_In
# Contains
# Continuous_With
# Created
# Definition
# Distal_to
# Domain_string
# Drains_Into
# External_to
# FMAID
# Freesurfer
# Has_Blood_Supply
# Has_Branch
# Has_Branch_Part
# Has_Constitutional_Part
# Has_Entrapment_Site
# Has_Innervation_Source
# Has_insertion
# Has_Member
# Has_origin
# Has_Part
# Has_Regional_Part
# Inferior_to
# Innervates
# Insertion_of
# JHU_DTI-81
# JHU_White-Matter_Tractography_Atlas
# Lymphatic_Drainage
# Lymphatic_Drainage_Of
# May_Be_Caused_By
# May_Cause
# Member_Of
# Misspelling_of_term
# name
# Origin_of
# Part_Of
# Posterior_to
# Preferred_name
# Preferred_Name_for_Obsolete
# Preferred_name_German
# Projects_From
# Projects_To
# Proximal_to
# Radlex_version_of_class_change
# Receives_attachment_from
# Receives_Drainage_From
# Receives_Input_From
# Receives_Projection_From
# Regional_Part_Of
# Related_modality
# Replaced_by
# RID50653
# Segment_Of
# Sends_Output_To
# SNOMED_ID
# SNOMED_Term
# Source
# Superior_to
# Surrounded_by
# Surrounds
# Synonym
# Synonym_German
# Talairach
# Term_type
# Tributary_Of
# UMLS_ID
# UMLS_Term
# Unsanctioned_Term

# %%
radlex_data["Class ID"] = radlex_data["Class ID"].str.replace("http://www.radlex.org/RID/", "", regex=False)
radlex_data["Parents"] = radlex_data["Parents"].str.replace("http://www.radlex.org/RID/", "", regex=False)
radlex_data = radlex_data[radlex_data["Obsolete"] == False]

radlex_data.head()
# Out:
#    Class ID                                    Preferred Label  \
# 0  RID32370  left fourth anterior cervical intertransversarius
# 1  RID21755  trunk of pharyngeal branch of right glossophar...
# 2  RID35046                                blade-of-grass sign
# 3  RID29220                                    layer of cornea
# 4  RID14565                     nerve to depressor anguli oris
#
#                     Synonyms  \
# 0                        NaN
# 1                        NaN
# 2  V sign of bone|flame sign
# 3                        NaN
# 4                        NaN
#
#                                          Definitions  Obsolete  CUI  \
# 0                                                NaN     False  NaN
# 1                                                NaN     False  NaN
# 2  A wedge- or V-shaped radiolucent area typicall...     False  NaN
# 3                                                NaN     False  NaN
# 4                                                NaN     False  NaN
#
#    Semantic Types   Parents http://data.bioontology.org/metadata/prefixIRI  \
# 0             NaN  RID32368                                  RID1:RID32370
# 1             NaN  RID21754                                  RID1:RID21755
# 2             NaN  RID29023                                  RID1:RID35046
# 3             NaN  RID29216                                  RID1:RID29220
# 4             NaN  RID14549                                  RID1:RID14565
#
#    AAL  ... Surrounded_by Surrounds Synonym Synonym_German Talairach  \
# 0  NaN  ...           NaN       NaN     NaN            NaN       NaN
# 1  NaN  ...           NaN       NaN     NaN            NaN       NaN
# 2  NaN  ...           NaN       NaN     NaN            NaN       NaN
# 3  NaN  ...           NaN       NaN     NaN            NaN       NaN
# 4  NaN  ...           NaN       NaN     NaN            NaN       NaN
#
#   Term_type Tributary_Of UMLS_ID UMLS_Term Unsanctioned_Term
# 0       NaN          NaN     NaN       NaN               NaN
# 1       NaN          NaN     NaN       NaN               NaN
# 2       NaN          NaN     NaN       NaN               NaN
# 3       NaN          NaN     NaN       NaN               NaN
# 4       NaN          NaN     NaN       NaN               NaN
#
# [5 rows x 170 columns]

# %%
radlex_data.shape
# Out:
# (46840, 170)

# %%
duplicates = radlex_data["Class ID"][radlex_data["Class ID"].duplicated()]
print(duplicates)
# Out:
# Series([], Name: Class ID, dtype: object)

# %%
import re

def count_rid_links(text):
    if pd.isna(text):
        return 0
    return len(re.findall(r"RID\w+", text))

# Apply the function to count RID links in each row
rid_link_counts = radlex_data["Parents"].apply(count_rid_links)

# Check the distribution of counts
print(rid_link_counts.value_counts())
# Out:
# Parents
# 1    46838
# 2        1
# 0        1
# Name: count, dtype: int64

# %%
radlex_data["Parent_Count"] = radlex_data["Parents"].apply(count_rid_links)

# Filter the row(s) with two parent links
rows_with_two_parents = radlex_data[radlex_data["Parent_Count"] == 2]

print(rows_with_two_parents["Parents"].values[0])
# Out:
# RID5|RID3

# %%
nan_counts = radlex_data.isna().sum()
print(nan_counts)
# Out:
# Class ID                 0
# Preferred Label          0
# Synonyms             33207
# Definitions          43036
# Obsolete                 0
#                      ...
# Tributary_Of         46840
# UMLS_ID              45517
# UMLS_Term            46840
# Unsanctioned_Term    46840
# Parent_Count             0
# Length: 171, dtype: int64

# %%
all_nan_columns = radlex_data.columns[radlex_data.isna().sum() == len(radlex_data)]
radlex_data = radlex_data.dropna(axis=1, how='all')

print("Dropped columns:", list(all_nan_columns))
# Out:
# Dropped columns: ['CUI', 'Semantic Types', 'Domain_string', 'name', 'SNOMED_Term', 'Term_type', 'Acronym', 'Anatomical_Site', 'Anterior_to', 'Attaches_to', 'Blood_Supply_of', 'Bounded_by', 'Bounds', 'Branch_Of', 'Branch_Part_of', 'CMA_Label', 'Comment', 'Constitutional_Part_Of', 'Contained_In', 'Contains', 'Continuous_With', 'Created', 'Definition', 'Distal_to', 'Domain_string', 'Drains_Into', 'External_to', 'FMAID', 'Has_Blood_Supply', 'Has_Branch', 'Has_Branch_Part', 'Has_Constitutional_Part', 'Has_Entrapment_Site', 'Has_Innervation_Source', 'Has_insertion', 'Has_Member', 'Has_origin', 'Has_Part', 'Has_Regional_Part', 'Inferior_to', 'Innervates', 'Insertion_of', 'JHU_DTI-81', 'JHU_White-Matter_Tractography_Atlas', 'Lymphatic_Drainage', 'Lymphatic_Drainage_Of', 'May_Be_Caused_By', 'May_Cause', 'Member_Of', 'Misspelling_of_term', 'name', 'Origin_of', 'Part_Of', 'Posterior_to', 'Preferred_name', 'Preferred_Name_for_Obsolete', 'Preferred_name_German', 'Projects_From', 'Projects_To', 'Proximal_to', 'Receives_attachment_from', 'Receives_Drainage_From', 'Receives_Input_From', 'Receives_Projection_From', 'Regional_Part_Of', 'Related_modality', 'Replaced_by', 'RID50653', 'Segment_Of', 'Sends_Output_To', 'SNOMED_Term', 'Source', 'Superior_to', 'Surrounded_by', 'Surrounds', 'Synonym', 'Term_type', 'Tributary_Of', 'UMLS_Term', 'Unsanctioned_Term']

# %%
radlex_data.shape
for col in radlex_data.columns:
    print(col)
# Out:
# Class ID
# Preferred Label
# Synonyms
# Definitions
# Obsolete
# Parents
# http://data.bioontology.org/metadata/prefixIRI
# AAL
# Acronym
# Anatomical_Site
# Anterior_to
# Attaches_to
# Blood_Supply_of
# Bounded_by
# Bounds
# Branch_Of
# CMA_Label
# Comment
# Constitutional_Part_Of
# Contained_In
# Contains
# Continuous_With
# Created
# Definition
# Distal_to
# Drains_Into
# External_to
# FMAID
# Freesurfer
# Has_Blood_Supply
# Has_Branch
# Has_Constitutional_Part
# Has_Entrapment_Site
# Has_Innervation_Source
# Has_insertion
# Has_Member
# Has_origin
# Has_Part
# Has_Regional_Part
# Inferior_to
# Innervates
# Insertion_of
# JHU_DTI-81
# JHU_White-Matter_Tractography_Atlas
# Lymphatic_Drainage
# Lymphatic_Drainage_Of
# May_Be_Caused_By
# May_Cause
# Member_Of
# Misspelling_of_term
# Origin_of
# Part_Of
# Posterior_to
# Preferred_name
# Preferred_Name_for_Obsolete
# Preferred_name_German
# Projects_From
# Projects_To
# Proximal_to
# Radlex_version_of_class_change
# Receives_attachment_from
# Receives_Drainage_From
# Receives_Input_From
# Receives_Projection_From
# Regional_Part_Of
# Related_modality
# Replaced_by
# Segment_Of
# Sends_Output_To
# SNOMED_ID
# Source
# Superior_to
# Surrounded_by
# Surrounds
# Synonym
# Synonym_German
# Talairach
# Tributary_Of
# UMLS_ID
# UMLS_Term
# Unsanctioned_Term
# http://www.geneontology.org/formats/oboInOwl#created_by
# http://www.geneontology.org/formats/oboInOwl#creation_date
# AAL
# Freesurfer
# Radlex_version_of_class_change
# SNOMED_ID
# Synonym_German
# Talairach
# UMLS_ID
# Parent_Count

# %% [markdown]
# ## Creating RadLex code-description pairs in English and German

# %%
relevant_cols = [
    "Class ID",
    "Preferred Label",
    "Synonyms",
    "Definitions",
    "Acronym",
    "Comment",
    "Definition",
    #"FMAID",
    "JHU_DTI-81",
    "JHU_White-Matter_Tractography_Atlas",
    "Misspelling_of_term",
    "Preferred_name",
    "Preferred_Name_for_Obsolete",
    "Preferred_name_German",
    #"Related_modality",
    #"Replaced_by",
    #"SNOMED_ID",
    "Synonym",
    "Synonym_German",
    #"UMLS_ID",
    #"UMLS_Term",
    "Unsanctioned_Term",
    #"http://www.geneontology.org/formats/oboInOwl#created_by",
    #"http://www.geneontology.org/formats/oboInOwl#creation_date",
    #"AAL",
    #"Freesurfer",
    #"Radlex_version_of_class_change",
    #"Talairach"
]

# Remove duplicates from the list
relevant_cols = list(dict.fromkeys(relevant_cols))  # preserves order and removes duplicates

# Filter only those columns that exist in the current DataFrame
columns_in_df = [col for col in relevant_cols if col in radlex_data.columns]

# Create the new DataFrame
radlex_llm = radlex_data[columns_in_df]

# Check which columns are duplicated
duplicate_cols = radlex_llm.columns.duplicated()
print("Are there duplicate columns?:", duplicate_cols.any())

# List duplicated column names
duplicates = radlex_llm.columns[duplicate_cols].to_list()
print("Duplicated columns:", duplicates)

# Remove duplicate columns, keep first occurrence
radlex_llm = radlex_llm.loc[:, ~radlex_llm.columns.duplicated()]

# Display summary
print(f"New dataframe created with {len(columns_in_df)} columns out of {len(relevant_cols)} requested.")
print(f"Missing columns (not found in DataFrame): {[col for col in relevant_cols if col not in radlex_data.columns]}")
# Out:
# Are there duplicate columns?: True
# Duplicated columns: ['Synonym_German']
# New dataframe created with 16 columns out of 16 requested.
# Missing columns (not found in DataFrame): []

# %%
radlex_llm.head(5)
# Out:
#    Class ID                                    Preferred Label  \
# 0  RID32370  left fourth anterior cervical intertransversarius
# 1  RID21755  trunk of pharyngeal branch of right glossophar...
# 2  RID35046                                blade-of-grass sign
# 3  RID29220                                    layer of cornea
# 4  RID14565                     nerve to depressor anguli oris
#
#                     Synonyms  \
# 0                        NaN
# 1                        NaN
# 2  V sign of bone|flame sign
# 3                        NaN
# 4                        NaN
#
#                                          Definitions Acronym  \
# 0                                                NaN     NaN
# 1                                                NaN     NaN
# 2  A wedge- or V-shaped radiolucent area typicall...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                              Comment  \
# 0                                                NaN
# 1                                                NaN
# 2  http://radiology.rsna.org/cgi/content/full/221...
# 3                                                NaN
# 4                                                NaN
#
#                                           Definition JHU_DTI-81  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2  A wedge- or V-shaped radiolucent area typicall...        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#   JHU_White-Matter_Tractography_Atlas Misspelling_of_term  \
# 0                                 NaN                 NaN
# 1                                 NaN                 NaN
# 2                                 NaN                 NaN
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
#
#                                       Preferred_name  \
# 0  left fourth anterior cervical intertransversarius
# 1  trunk of pharyngeal branch of right glossophar...
# 2                                blade-of-grass sign
# 3                                    layer of cornea
# 4                     nerve to depressor anguli oris
#
#   Preferred_Name_for_Obsolete  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                Preferred_name_German  \
# 0  linker Musculus intertransversarius anterior c...
# 1  Truncus des Ramus pharyngeus des rechten Nervu...
# 2                           blade-of-grass sign (EN)
# 3                                 Schicht der Cornea
# 4            Nerv zum Musculus depressor anguli oris
#
#                      Synonym Synonym_German Unsanctioned_Term
# 0                        NaN            NaN               NaN
# 1                        NaN            NaN               NaN
# 2  V sign of bone|flame sign            NaN               NaN
# 3                        NaN            NaN               NaN
# 4                        NaN            NaN               NaN

# %%
radlex_llm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46840 entries, 0 to 46839
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Class ID                             46840 non-null  object
#  1   Preferred Label                      46840 non-null  object
#  2   Synonyms                             13633 non-null  object
#  3   Definitions                          3804 non-null   object
#  4   Acronym                              133 non-null    object
#  5   Comment                              1866 non-null   object
#  6   Definition                           3804 non-null   object
#  7   JHU_DTI-81                           49 non-null     object
#  8   JHU_White-Matter_Tractography_Atlas  16 non-null     object
#  9   Misspelling_of_term                  33 non-null     object
#  10  Preferred_name                       45928 non-null  object
#  11  Preferred_Name_for_Obsolete          939 non-null    object
#  12  Preferred_name_German                45171 non-null  object
#  13  Synonym                              13633 non-null  object
#  14  Synonym_German                       2020 non-null   object
#  15  Unsanctioned_Term                    54 non-null     object
# dtypes: object(16)
# memory usage: 5.7+ MB

# %%
#radlex_llm["Freesurfer"].describe(include='all')
#unique_values = radlex_llm["Freesurfer"].dropna()
#print(unique_values)

# %%
# Select rows where neither column is NaN
both_non_nan = radlex_data["Definitions"].notna() & radlex_data["Definition"].notna()

# Compare those rows
differs = radlex_data.loc[both_non_nan, "Definitions"] != radlex_data.loc[both_non_nan, "Definition"]

if differs.any():
    print(f"Columns differ in {differs.sum()} rows where both are non-NaN.")
    # Show some differing rows for inspection
    print(radlex_data.loc[both_non_nan & differs, ["Definitions", "Definition"]])
else:
    print("No differences found in non-NaN entries. Dropping 'Definition' column.")
    radlex_data = radlex_data.drop(columns=["Definition"])
# Out:
# No differences found in non-NaN entries. Dropping 'Definition' column.

# %%
radlex_llm.describe(include='all')
# Out:
#         Class ID                                    Preferred Label Synonyms  \
# count      46840                                              46840    13633
# unique     46840                                              46830    13588
# top     RID32370  plexus branch of anterior branch of left later...     mass
# freq           1                                                  2        4
#
#                                               Definitions Acronym    Comment  \
# count                                                3804     133       1866
# unique                                               3748     132        995
# top     Reactive vertebral body modifications associat...      MI  duplicate
# freq                                                    4       2        297
#
#                                                Definition  \
# count                                                3804
# unique                                               3748
# top     Reactive vertebral body modifications associat...
# freq                                                    4
#
#                           JHU_DTI-81 JHU_White-Matter_Tractography_Atlas  \
# count                             49                                  16
# unique                            49                                  16
# top     Cingulum (cingulate gyrus) R               Corticospinal tract L
# freq                               1                                   1
#
#        Misspelling_of_term     Preferred_name  \
# count                   33              45928
# unique                  33              45918
# top        Segund fracture  molecular imaging
# freq                     1                  2
#
#                 Preferred_Name_for_Obsolete      Preferred_name_German  \
# count                                   939                      45171
# unique                                  937                      44408
# top     middle para-aortic lymph node group  linker Lemniscus medialis
# freq                                      2                          3
#
#        Synonym Synonym_German      Unsanctioned_Term
# count    13633           2020                     54
# unique   13588           1995                     54
# top       mass        Mamille  casting calcification
# freq         4              8                      1

# %% [markdown]
# ## Export RadLex code-description pairs in English

# %%
radlex_llm
# Out:
#        Class ID                                    Preferred Label  \
# 0      RID32370  left fourth anterior cervical intertransversarius
# 1      RID21755  trunk of pharyngeal branch of right glossophar...
# 2      RID35046                                blade-of-grass sign
# 3      RID29220                                    layer of cornea
# 4      RID14565                     nerve to depressor anguli oris
# ...         ...                                                ...
# 46835  RID11044                                monorail deployment
# 46836  RID17476  c5 segment of right gracile fasciculus of spin...
# 46837  RID36158                         left inferior orbital vein
# 46838  RID44006                                   subscapular vein
# 46839  RID32362       second anterior cervical intertransversarius
#
#                         Synonyms  \
# 0                            NaN
# 1                            NaN
# 2      V sign of bone|flame sign
# 3                            NaN
# 4                            NaN
# ...                          ...
# 46835                        NaN
# 46836                        NaN
# 46837                        NaN
# 46838         vena subscapularis
# 46839                        NaN
#
#                                              Definitions Acronym  \
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2      A wedge- or V-shaped radiolucent area typicall...     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 46835                                                NaN     NaN
# 46836                                                NaN     NaN
# 46837                                                NaN     NaN
# 46838                                                NaN     NaN
# 46839                                                NaN     NaN
#
#                                                  Comment  \
# 0                                                    NaN
# 1                                                    NaN
# 2      http://radiology.rsna.org/cgi/content/full/221...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 46835                                                NaN
# 46836                                                NaN
# 46837                                                NaN
# 46838                                                NaN
# 46839                                                NaN
#
#                                               Definition JHU_DTI-81  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2      A wedge- or V-shaped radiolucent area typicall...        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 46835                                                NaN        NaN
# 46836                                                NaN        NaN
# 46837                                                NaN        NaN
# 46838                                                NaN        NaN
# 46839                                                NaN        NaN
#
#       JHU_White-Matter_Tractography_Atlas Misspelling_of_term  \
# 0                                     NaN                 NaN
# 1                                     NaN                 NaN
# 2                                     NaN                 NaN
# 3                                     NaN                 NaN
# 4                                     NaN                 NaN
# ...                                   ...                 ...
# 46835                                 NaN                 NaN
# 46836                                 NaN                 NaN
# 46837                                 NaN                 NaN
# 46838                                 NaN                 NaN
# 46839                                 NaN                 NaN
#
#                                           Preferred_name  \
# 0      left fourth anterior cervical intertransversarius
# 1      trunk of pharyngeal branch of right glossophar...
# 2                                    blade-of-grass sign
# 3                                        layer of cornea
# 4                         nerve to depressor anguli oris
# ...                                                  ...
# 46835                                monorail deployment
# 46836  c5 segment of right gracile fasciculus of spin...
# 46837                         left inferior orbital vein
# 46838                                   subscapular vein
# 46839       second anterior cervical intertransversarius
#
#       Preferred_Name_for_Obsolete  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 46835                         NaN
# 46836                         NaN
# 46837                         NaN
# 46838                         NaN
# 46839                         NaN
#
#                                    Preferred_name_German  \
# 0      linker Musculus intertransversarius anterior c...
# 1      Truncus des Ramus pharyngeus des rechten Nervu...
# 2                               blade-of-grass sign (EN)
# 3                                     Schicht der Cornea
# 4                Nerv zum Musculus depressor anguli oris
# ...                                                  ...
# 46835                                   Monorail-Einsatz
# 46836  Segment C5 des rechten Fasciculus gracilis des...
# 46837                      linke Vena orbitalis inferior
# 46838                                 vena subscapularis
# 46839  Musculus intertransversarius anterior cervicis II
#
#                          Synonym Synonym_German Unsanctioned_Term
# 0                            NaN            NaN               NaN
# 1                            NaN            NaN               NaN
# 2      V sign of bone|flame sign            NaN               NaN
# 3                            NaN            NaN               NaN
# 4                            NaN            NaN               NaN
# ...                          ...            ...               ...
# 46835                        NaN            NaN               NaN
# 46836                        NaN            NaN               NaN
# 46837                        NaN            NaN               NaN
# 46838         vena subscapularis            NaN               NaN
# 46839                        NaN            NaN               NaN
#
# [46840 rows x 16 columns]

# %%
# Filter rows where Class ID is NOT a string or doesn't start with 'RID'
invalid_ids = radlex_llm[~radlex_llm["Class ID"].astype(str).str.startswith("RID")]

# Show them
invalid_ids
# Out:
#               Class ID  Preferred Label Synonyms Definitions Acronym Comment  \
# 20724      RadLex_term      RadLex term      NaN         NaN     NaN     NaN
# 31325  Non-RadLex_term  Non-RadLex term      NaN         NaN     NaN     NaN
#
#       Definition JHU_DTI-81 JHU_White-Matter_Tractography_Atlas  \
# 20724        NaN        NaN                                 NaN
# 31325        NaN        NaN                                 NaN
#
#       Misspelling_of_term Preferred_name Preferred_Name_for_Obsolete  \
# 20724                 NaN            NaN                         NaN
# 31325                 NaN            NaN                         NaN
#
#       Preferred_name_German Synonym Synonym_German Unsanctioned_Term
# 20724                   NaN     NaN            NaN               NaN
# 31325                   NaN     NaN            NaN               NaN

# %%
# Filter rows where Class ID is NOT a string or doesn't start with 'RID' (THESE ROWS ARE OBSOLOTE)
invalid_descriptions = radlex_llm[radlex_llm["Preferred Label"].astype(str).str.startswith("RID")]

# Show them
invalid_descriptions
# Out:
#        Class ID Preferred Label Synonyms Definitions Acronym  \
# 31     RID10853        RID10853      NaN         NaN     NaN
# 84       RID469          RID469      NaN         NaN     NaN
# 138    RID28845        RID28845      NaN         NaN     NaN
# 160      RID470          RID470      NaN         NaN     NaN
# 325      RID678          RID678      NaN         NaN     NaN
# ...         ...             ...      ...         ...     ...
# 46564  RID15043        RID15043      NaN         NaN     NaN
# 46601  RID12602        RID12602      NaN         NaN     NaN
# 46692  RID32047        RID32047      NaN         NaN     NaN
# 46776  RID15039        RID15039      NaN         NaN     NaN
# 46821  RID12805        RID12805      NaN         NaN     NaN
#
#                                                  Comment Definition  \
# 31     Children moved to "ultrasound transducer"; not...        NaN
# 84                                             duplicate        NaN
# 138                                     no longer needed        NaN
# 160                                            duplicate        NaN
# 325    seems to be an erroneous term for a branch of ...        NaN
# ...                                                  ...        ...
# 46564                                          duplicate        NaN
# 46601  Deleted all "procedure step" terms.  These wer...        NaN
# 46692                                          duplicate        NaN
# 46776                                          duplicate        NaN
# 46821  Was used as an instance-level  slot for a proc...        NaN
#
#       JHU_DTI-81 JHU_White-Matter_Tractography_Atlas Misspelling_of_term  \
# 31           NaN                                 NaN                 NaN
# 84           NaN                                 NaN                 NaN
# 138          NaN                                 NaN                 NaN
# 160          NaN                                 NaN                 NaN
# 325          NaN                                 NaN                 NaN
# ...          ...                                 ...                 ...
# 46564        NaN                                 NaN                 NaN
# 46601        NaN                                 NaN                 NaN
# 46692        NaN                                 NaN                 NaN
# 46776        NaN                                 NaN                 NaN
# 46821        NaN                                 NaN                 NaN
#
#       Preferred_name                        Preferred_Name_for_Obsolete  \
# 31               NaN                        ultrasound transducer shape
# 84               NaN                     left lower quadrant of abdomen
# 138              NaN                             xray imaging procedure
# 160              NaN                     left upper quadrant of abdomen
# 325              NaN                                     angular artery
# ...              ...                                                ...
# 46564            NaN  medial proper palmar digital branch of median ...
# 46601            NaN          intrinsic uniformity quality control step
# 46692            NaN                     left lateral aortic lymph node
# 46776            NaN  medial proper palmar digital branch of median ...
# 46821            NaN                                   injection method
#
#       Preferred_name_German Synonym Synonym_German Unsanctioned_Term
# 31                      NaN     NaN            NaN               NaN
# 84                      NaN     NaN            NaN               NaN
# 138                     NaN     NaN            NaN               NaN
# 160                     NaN     NaN            NaN               NaN
# 325                     NaN     NaN            NaN               NaN
# ...                     ...     ...            ...               ...
# 46564                   NaN     NaN            NaN               NaN
# 46601                   NaN     NaN            NaN               NaN
# 46692                   NaN     NaN            NaN               NaN
# 46776                   NaN     NaN            NaN               NaN
# 46821                   NaN     NaN            NaN               NaN
#
# [910 rows x 16 columns]

# %%
radlex_llm = radlex_llm[radlex_llm["Class ID"].astype(str).str.startswith("RID")]
radlex_llm = radlex_llm[~radlex_llm["Preferred Label"].astype(str).str.startswith("RID")]
radlex_llm.shape
# Out:
# (45928, 16)

# %%
# Select and rename the columns
radlex_df = radlex_llm[["Class ID", "Preferred Label"]].rename(
    columns={"Class ID": "radlex_code", "Preferred Label": "preferred_description"}
)

# Save to CSV
radlex_df.to_csv("d_radlex_entities.csv", index=False)
